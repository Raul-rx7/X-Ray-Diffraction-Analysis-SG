# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, cufflinks as cf, plotly.express as px
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %matplotlib inline
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
a2 = pd.read_fwf('Amostra B.txt')
a2.to_csv('Amostra B.csv')

a2 = pd.read_csv('Amostra B.csv', names=['x', 'y'])
a2 = a2[['x', 'y']].dropna()
a2.head()
# Out:
#         x       y
# NaN  5.00   2.500
# 0.0  5.02   0.000
# 1.0  5.04   6.667
# 2.0  5.06   0.833
# 3.0  5.08  10.000

# %% [markdown]
# ## Plotando o Difratograma com a biblioteca matplotlib:

# %%
plt.figure(figsize=(10, 4), clear=True)
plt.plot(a2['x'], a2['y'], color='blue', linewidth=0.2)
plt.xlabel(r'2$\theta$(graus)')
plt.ylabel('Intensidade(CPS)')
plt.legend(['Amostra 2'], loc=1)
plt.title('DRX');

# %% [markdown]
# ## Plotando com a biblioteca Plotly:
#
# É possível plotar um gráfico interativo e verificar os pontos cruciais para a análise do material em questão.

# %%
px.line(a2, x="x", y="y", title='DRX: Amostra 2', labels={'x': 'Graus(°) ', 'y':'Intensidade(CPS)'})
# Out:
# <div>                            <div id="57ad4ee0-d173-4577-b7d9-5ac9492015fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57ad4ee0-d173-4577-b7d9-5ac9492015fe")) {                    Plotly.newPlot(                        "57ad4ee0-d173-4577-b7d9-5ac9492015fe",                        [{"hovertemplate":"Graus(\u00b0) =%{x}<br>Intensidade(CPS)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":[5.0,5.02,5.04,5.06,5.08,5.1,5.12,5.14,5.16,5.18,5.2,5.22,5.24,5.26,5.28,5.3,5.32,5.34,5.36,5.38,5.4,5.42,5.44,5.46,5.48,5.5,5.52,5.54,5.56,5.58,5.6,5.62,5.64,5.66,5.68,5.7,5.72,5.74,5.76,5.78,5.8,5.82,5.84,5.86,5.88,5.9,5.92,5.94,5.96,5.98,6.0,6.02,6.04,6.06,6.
# ...
